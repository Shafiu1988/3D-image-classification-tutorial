# %% [markdown]
# <a href="https://colab.research.google.com/github/Shafiu1988/3D-image-classification-tutorial/blob/master/TRIAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile
import numpy as np
import tensorflow as tf
import tkinter
import matplotlib.pyplot as plt
import cv2
import PIL
import PIL.Image
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image as img
from keras.preprocessing.image import load_img
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D

# %%
# %matplotlib inline
from keras.preprocessing import image

# %%
img = np.random.rand(243,272,3)
plt.imshow(img)
plt.show()

# %%
img_path = '/content/shafiu.JPG'
img = load_img(img_path, target_size=(3648,5472))
print(type(img))

# %%
x = image.img_to_array(img)
print(type(x))
print(x.shape)
plt.imshow(x)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <class 'numpy.ndarray'>
# (242, 272, 3)

# %%
print(type(img_path))
# Out:
# <class 'str'>

# %%
print(x.shape)
